# %%
s="HellO"

# %%
s
# Out:
# 'HellO'

# %%
s.swapcase()
# Out:
# 'hELLo'

# %%
h='    hill      '

# %%
h
# Out:
# '    hill      '

# %%
h.strip()
# Out:
# 'hill'

# %%
s="malayalam"

# %%
s
# Out:
# 'malayalam'

# %%
s==s[::-1]
# Out:
# True

# %%
s="abc#abd"

# %%
s.split("#")
# Out:
# ['abc', 'abd']

# %%
id(s)
# Out:
# 140385442757744

# %%
s="kiii"

# %%
id(s)
# Out:
# 140385495800608

# %%
s[0]="i"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4c9eb5bcc547> in <module>
# ----> 1 s[0]="i"
#
# TypeError: 'str' object does not support item assignment

# %%
"""reason why python string is Immutable because if s="hii" and we ad s="hello" the address of 1 s will be different than the second one"""
