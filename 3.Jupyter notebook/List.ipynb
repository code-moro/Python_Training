# %%
#typecasting

number = int(input())
if number %2 ==0:
    print("Even")
else:
    print("odd")
# Out:
# 3
# odd

# %%
"""
int(x)
float(x)
str(x)
"""

# %%
#for looping

# %%
for i in 'python':
    print(i,end=' ')
# Out:
# p y t h o n

# %%
num=int(input("Enter The Number"))
fact=1
for i in range(2,num+1):
    fact=fact*i
print(fact)
# Out:
# Enter The Number5
# 120

# %%
#list
lst=[1,2,3,4,'adi','hi',1.0]

# %%
lst
# Out:
# [1, 2, 3, 4, 'adi', 'hi', 1.0]

# %%
type(lst)
# Out:
# list

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
#print last element from the list
lst[-1]
# Out:
# 1.0

# %%
#add 5 in second position
lst.insert(2,5)

# %%
lst
# Out:
# [1, 2, 5, 3, 4, 'adi', 'hi', 1.0]

# %%
#to access the complex string
lst[5][2]
# Out:
# 'i'

# %%
#for loop in 
for i in lst:
    print(i)
# Out:
# 1
# 2
# 5
# 3
# 4
# adi
# hi
# 1.0

# %%
type(lst)
# Out:
# list

# %%
#List in Iterable ,mutable
#can hold Different data type

# %%
id(lst[0])
# Out:
# 94438840158752

# %%
lst[0]=456

# %%
lst
# Out:
# [456, 2, 5, 3, 4, 'adi', 'hi', 1.0]

# %%
id(lst[0])
# Out:
# 140608263394416

# %%
id(lst)
# Out:
# 140608243335432

# %%
lst[0]=1

# %%
id(lst)
# Out:
# 140608243335432

# %%
#removes last element from list
lst.pop()
# Out:
# 'hi'

# %%
lst
# Out:
# [1, 2, 5, 3, 4, 'adi']

# %%
#to remove specific element of index 3
lst.remove(3)

# %%
lst
# Out:
# [1, 2, 5, 4, 'adi']

# %%
#if what to print element of specifi type for eg integer 
#if list[1,3,4,"hello",0.7,"jii"]

# %%
lst2=[1,2,4,"hello","bye","go"]

# %%
for i in lst2:
    if isinstance(i,int):
        print("int type",i)
# Out:
# int type 1
# int type 2
# int type 4

# %%
ll=list(range(2,11,2))

# %%
ll
# Out:
# [2, 4, 6, 8, 10]
