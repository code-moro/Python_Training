# %%
#dictionary 
# mutuable,non-index,iterable 
#it holds key value pair
#here key is immutable and value is mutable
#it can hold different datatypes like str,int,float

# %%
mydict={}

# %%
type(mydict)
# Out:
# dict

# %%
mydict1=dict()

# %%
type(mydict1)
# Out:
# dict

# %%
mydict["k1"]="mayur"

# %%
mydict
# Out:
# {'k1': 'mayur'}

# %%
len(mydict)
# Out:
# 1

# %%
mydict={'k2':"hii",'k3':"hello",'k4':"mayur"}

# %%
mydict
# Out:
# {'k2': 'hii', 'k3': 'hello', 'k4': 'mayur'}

# %%
mydict.keys()
# Out:
# dict_keys(['k2', 'k3', 'k4'])

# %%
mydict={'mayur':1,'cards':{'hdfc':'code','icic':2}}

# %%
mydict['cards']['hdfc'][-1]
# Out:
# 'e'

# %%
for i in mydict:
    print(i)
# Out:
# mayur
# cards

# %%
for i in mydict.values():
    print(i)
# Out:
# 1
# {'hdfc': 'code', 'icic': 2}

# %%
for i in mydict.items():
    print(i)
# Out:
# ('mayur', 1)
# ('cards', {'hdfc': 'code', 'icic': 2})

# %%
dir(mydict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
mydict={'pack':{23,45,67}}

# %%
mydict
# Out:
# {'pack': {23, 45, 67}}

# %%
d={'a':100,'b':200,'c':300,'v':[1,2,3,4]}

# %%
d['v'][0]
# Out:
# 1

# %%
d['v'][1]
# Out:
# 2

# %%
for i in d['v']:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
d['v'][0]
# Out:
# 1
